# %% [markdown]
# # JSON Dataset

# %%
import pandas as pd

# %%
# Dataset loaded from the files 
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# Dataset loaded from URL-API 
pd.read_json('https://api.stackexchange.com/2.2/search?order=desc&sort=activity&intitle=perl&site=stackoverflow')
# Out:
#                                                 items  has_more  quota_max  \
# 0   {'tags': ['perl', 'installation', 'makefile', ...      True        300
# 1   {'tags': ['windows', 'perl', 'imagemagick', 's...      True        300
# 2   {'tags': ['perl'], 'owner': {'reputation': 159...      True        300
# 3   {'tags': ['perl'], 'owner': {'reputation': 528...      True        300
# 4   {'tags': ['regex', 'perl', 'awk', 'sed'], 'own...      True        300
# 5   {'tags': ['ruby', 'debugging'], 'owner': {'rep...      True        300
# 6   {'tags': ['perl', 'xs'], 'owner': {'reputation...      True        300
# 7   {'tags': ['arrays', 'perl', 'hash'], 'owner': ...      True        300
# 8   {'tags': ['perl', 'imagemagick', 'cpan', 'stra...      True        300
# 9   {'tags': ['r', 'regex'], 'owner': {'reputation...      True        300
# 10  {'tags': ['mysql', 'perl', 'dbd'], 'owner': {'...      True        300
# ...

# %%
# Dataset loaded from URL
pd.read_json('https://www.floatrates.com/daily/usd.json')
# Out:
#                                       aud                           cad  \
# code                                  AUD                           CAD
# alphaCode                             AUD                           CAD
# numericCode                           036                           124
# name                    Australian Dollar               Canadian Dollar
# rate                             1.512564                      1.380442
# date         Tue, 9 Sep 2025 16:55:05 GMT  Tue, 9 Sep 2025 16:55:05 GMT
# inverseRate                      0.661129                      0.724406
#
#                                       chf                           cny  \
# code                                  CHF                           CNY
# alphaCode                             CHF                           CNY
# numericCode                           756                           156
# name                          Swiss Franc                  Chinese Yuan
# ...

# %% [markdown]
# # SQL Dataset

# %% [markdown]
# ### For handling SQL dataset, I have downloaded the dataset from Kaggle. Imported the dataset name "World.sql" into XAMPP database. I have started the MYSQL and Apache in XAMPP control panel. To connect MYSQL dataset to pandas I have implemented below code. SQL query language is used to visualize the dataset

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.4 MB 4.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.6/16.4 MB 4.7 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/16.4 MB 4.7 MB/s eta 0:00:03
#    -------- ------------------------------- 3.4/16.4 MB 4.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.5/16.4 MB 4.7 MB/s eta 0:00:03
#    ------------- -------------------------- 5.5/16.4 MB 4.7 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.4 MB 4.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.3/16.4 MB 4.7 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.4 MB 4.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.4 MB 4.7 MB/s eta 0:00:02
#    ------------------------ --------------- 10.2/16.4 MB 4.7 MB/s eta 0:00:02
# ...

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\91887\anaconda3\envs\Newenv\python.exe

# %%
import sys
# !{sys.executable} -m pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-9.4.0-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Using cached mysql_connector_python-9.4.0-cp313-cp313-win_amd64.whl (16.4 MB)
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM city",conn)
# Out:
# C:\Users\91887\AppData\Local\Temp\ipykernel_8916\374620591.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'  ",conn)
# Out:
# C:\Users\91887\AppData\Local\Temp\ipykernel_8916\4163362351.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'  ",conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy> 60 ",conn)
# Out:
# C:\Users\91887\AppData\Local\Temp\ipykernel_8916\1605978896.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy> 60 ",conn)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# ...

# %%
pd.read_sql_query("SELECT * FROM countrylanguage",conn)
# Out:
# C:\Users\91887\AppData\Local\Temp\ipykernel_8916\4078718901.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM countrylanguage",conn)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
